# %% [markdown]
# #  Linear Networks & Basic Optimization
#
# ###  **DSBA 6165: AI & Deep Learning**

# %% [markdown]
# ## Goal
#
# The goal of this lab activity is practicing to build a simple linear network, apply basic optimization and play with autograd tools. For the practice, we use Auto MPG dataset from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/).
#
# Along the way, we'll see how to build and train a linear network. Additionally, we will take a look at gradient descent which allows us to iteratively minimize the error (loss) and can help our network the optimal solution (linear). Additionally, we'll look at how we can use a automatic differention manually to understand its underlying behavior.

# %% [markdown]
# ## Loading Data

# %% [markdown]
# Let us first import the libraries we are going to use. TensorFlow for DL models, matplotlib for plotting data/results, numpy and pandas for data handling.

# %%
import tensorflow as tf
from tensorflow import keras
from keras import layers
print("TF version:", tf.__version__)

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
# Out:
# TF version: 2.18.0

# %% [markdown]
# ### Auto-MPG Dataset
#
# You can navigate [UCI auto-mpg data folder](https://archive.ics.uci.edu/ml/datasets/Auto+MPG) to find [auto-mpg.data](https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data). Click the link and take a look at the data before starting to work the following TODOs.
#
#
# <img src="https://archive.ics.uci.edu/ml/assets/MLimages/Large9.jpg" width=350 />
#
#
# |  |  |  |  |  |  |
# |---|---|---|---|---|---|
# | Data Set Characteristics:&nbsp;&nbsp; | Multivariate | Number of Instances: | 398 | Area: | N/A |
# | Attribute Characteristics: | Categorical, Real | Number of Attributes: | 8 | Date Donated | 1993-07-07 |
# | Associated Tasks: | Regression | Missing Values? | Yes | Number of Web Hits: | 821244 |
#
#
#
# The dataset contains the following attributes:
#
# 1. mpg: continuous
# 2. cylinders: multi-valued discrete
# 3. displacement: continuous
# 4. horsepower: continuous
# 5. weight: continuous
# 6. acceleration: continuous
# 7. model year: multi-valued discrete
# 8. origin: multi-valued discrete
# 9. car name: string (unique for each instance)
#
# Given the other attributes as input feature, we can train the model to predict mpg or hoursepower, etc.

# %% [markdown]
# ### TODO1
#
# 1. Copy the auto-mpg.data url from above and define the variable `data_url`.
# 1. Load the auto-mpg dataset with the `data_url` provided below and store the output into `dfauto` using pandas `read_csv`.
#     1. Hint: Make sure to include the data url variable.
#     1. Hint: Use the read_csv reference here: [link](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html)
#     1. Hint: When you load the data, check the file format (delimiter), non-numeric content, etc. to pass a proper parameters. Use options `names`, `na_values`, and `delim_whitespace`.

# %%
# TODO: copy and paste the url here
data_url = "https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data"

# Feature names
colnames = ["mpg", "cylinders", "displacement", "horsepower", "weight",
            "acceleration", "model year", "origin", "car name"]

# TODO: read the data
dfauto = pd.read_csv(data_url, names=colnames, na_values="?", sep="\s+", skipinitialspace=True)





# display the dfdauto
display(dfauto)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# 1            70       1          buick skylark 320
# 2            70       1         plymouth satellite
# 3            70       1              amc rebel sst
# 4            70       1                ford torino
# ..          ...     ...                        ...
# 393          82       1            ford mustang gl
# 394          82       2                  vw pickup
# 395          82       1              dodge rampage
# 396          82       1                ford ranger
# 397          82       1                 chevy s-10
#
# [398 rows x 9 columns]

# %% [markdown]
#
#  ### TODO 1-1

# %% [markdown]
# Now we are Dropping the "car name" variable since it's an object which has many unique samples and not meaningfull for our findings
# 1. Drop the 'car name' variable from dataset using `drop`.
#   1. HINT: you can find detailed documentation here :[pandas.DataFrame.drop](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop.html)

# %%
# TODO:
df_data = dfauto.drop('car name', axis=1)
df_data
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      model year  origin
# 0            70       1
# 1            70       1
# 2            70       1
# 3            70       1
# 4            70       1
# ..          ...     ...
# 393          82       1
# 394          82       2
# 395          82       1
# 396          82       1
# 397          82       1
#
# [398 rows x 8 columns]

# %% [markdown]
# <Add sentences to explain>

# %% [markdown]
# Now we have dropped the 'car name' input. Now we should check whether the dataset contains any missing or improper values. We can use `isna` which return boolean values for the NA (or NaN, not a number) entries. `sum` function helps us count the number of NA values.

# %%
df_data.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model year      0
# origin          0
# dtype: int64

# %% [markdown]
# We are able to see six NA samples in the "horsepower" variable. Let's what samples they are:

# %%
df_data[df_data['horsepower'].isna()]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 32   25.0          4          98.0         NaN  2046.0          19.0
# 126  21.0          6         200.0         NaN  2875.0          17.0
# 330  40.9          4          85.0         NaN  1835.0          17.3
# 336  23.6          4         140.0         NaN  2905.0          14.3
# 354  34.5          4         100.0         NaN  2320.0          15.8
# 374  23.0          4         151.0         NaN  3035.0          20.5
#
#      model year  origin
# 32           71       1
# 126          74       1
# 330          80       2
# 336          80       1
# 354          81       2
# 374          82       1

# %% [markdown]
# We now need to remove the NaN values from the dataset because machine learning algorithms cannot handle non-numerical values. Additionally, it may be challenging to visualize or understand the data when a dataset contains NaN values. Analyses can be made clearer and more precise by eliminating NaN values. Of course, there are other ways to handle this other than simple removal. If you are interested in more data preprocessing methods to handling missing values, you can review Applied Machine Learning class.
#
#
#  ### TODO 1-2
# 1. Remove the data samples with NAs by using `dropna`. You can refer to this link for reference: [pandas.DataFrame.dropna](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dropna.html)

# %%
# TODO:
df_data = df_data.dropna()
df_data
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      model year  origin
# 0            70       1
# 1            70       1
# 2            70       1
# 3            70       1
# 4            70       1
# ..          ...     ...
# 393          82       1
# 394          82       2
# 395          82       1
# 396          82       1
# 397          82       1
#
# [392 rows x 8 columns]

# %% [markdown]
# Now we are mapping `origin` variable values to individual categorical so It can make easier to understand the data and perform further analysis, Using map function to replace these numerical values with their corresponding category names.

# %%
df_data['origin'].map({1: 'USA', 2: 'Europe', 3: 'Japan'})
# Out:
# 0         USA
# 1         USA
# 2         USA
# 3         USA
# 4         USA
#         ...
# 393       USA
# 394    Europe
# 395       USA
# 396       USA
# 397       USA
# Name: origin, Length: 392, dtype: object

# %% [markdown]
# The previous cell does show how map works without actually updating the column. Now let us update the origin to categorical variables of USA,EUROPE and JAPAN.

# %%
df_data['origin'] = df_data['origin'].map({1: 'USA', 2: 'Europe', 3: 'Japan'})
# Out:
# <ipython-input-8-8f32c3c3bf26>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_data['origin'] = df_data['origin'].map({1: 'USA', 2: 'Europe', 3: 'Japan'})

# %% [markdown]
# Most of the algorithms can not handle non-numerical variables unless we convert them to numerical values. Many algorithm’s performances vary based on how Categorical variables are encoded. Then, why do we need to convert numerical values to characters? Let us review dummy values.
#
#
# Dummy Encoding (a.k.a. one hot encoding) refers to an encoding strategy to convert a categorical feature to a numerical vector format.
# In this method, we map each category to a binary vector that contains the numbers 1 and 0, signifying whether the feature is present or not. The number of feature categories affects how many vectors there are. When we have `origin` has 1, 2, and 3 for cars from USA, EUROPE, and JAPAN, relation between these number can cause an issue. For instance, 2 > 1, so EUROPE > USA. What does that mean. USA cars are closer (2-1) to EUROPE than JAPAN (3-1)? Breaking this releation with dummy variables is very helpful to boost learning as Yan Lecun discussed in [Efficient Backprop paper](https://cseweb.ucsd.edu/classes/wi08/cse253/Handouts/lecun-98b.pdf).
#
#
# `pd.get_dummies` is a function from Pandas that performs dummy encoding in a single line of code. You can find detailed documentation here: [pandas.get_dummies](https://pandas.pydata.org/docs/reference/api/pandas.get_dummies.html)

# %% [markdown]
# ### TODO 1-3
#
# 1. Convert the column 'origin' to dummy variables.
#   1. Hint: Don't forget to use prefix and prefix seperator to have same column names. Refer to the above link if you need.

# %%
# TODO:
df_data = pd.get_dummies(df_data, columns=['origin'], prefix='', prefix_sep='')
df_data
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      model year  Europe  Japan    USA
# 0            70   False  False   True
# 1            70   False  False   True
# 2            70   False  False   True
# 3            70   False  False   True
# 4            70   False  False   True
# ..          ...     ...    ...    ...
# 393          82   False  False   True
# 394          82    True  False  False
# 395          82   False  False   True
# 396          82   False  False   True
# 397          82   False  False   True
#
# [392 rows x 10 columns]

# %% [markdown]
# ## Visualize the data
#  Seaborn, a visualization library, helps to visualize data with many plotting functions. To understand how variables in a dataset are related to one another and how that relationship is dependent on other variables, we can run visual analysis. This helps to visualize the trends and identify various patterns in the dataset.
#
# ### TODO 2
# 1. Using the seaborn `pairplot` plot, visualize the relationship between the following varaibles ('mpg', 'cylinder', 'horsepower', 'weight', 'acceleration') using diag_kind as kernel density estimation "kde".

# %%
# TODO: you code here
import seaborn as sns
selected_columns = df_data[['mpg', 'cylinders', 'horsepower', 'weight', 'acceleration']]
sns.pairplot(selected_columns, diag_kind="kde")

# %% [markdown]
# ## Data Split

# %% [markdown]
# Now we have to split the training and testing data because it allows us to estimate the model's performance on new data and ensure that the model is not overfitting, which is when a model performs well on the training data but poorly on new data. By evaluating the model's performance on unseen data, we can get a better understanding of how well the model will perform when used in practice.

# %%
train_data = df_data.sample(frac=0.8, random_state=0)#Splitting the data(80% for training and 20% for testing)
test_data = df_data.drop(train_data.index)

# %%
train_data.shape, test_data.shape
# Out:
# ((314, 10), (78, 10))

# %% [markdown]
# The 'mpg' column is eliminated using the `pop` method. Refer to this link for `pop` method.[Link](https://python-reference.readthedocs.io/en/latest/docs/list/pop.html).
# The reason for removing the output variable is we are essentially creating a dataset that only contains the input features, and not the target variable, for the testing set.
# This is usually done when evaluating the performance of a model.

# %%
x_train = train_data.copy()
x_test = test_data.copy()

y_train = x_train.pop('mpg')
y_test = x_test.pop('mpg')

# %%
display(x_train)
display(x_test)
display(y_train)
display(y_test)
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model year  \
# 146          4          90.0        75.0  2125.0          14.5          74
# 282          4         140.0        88.0  2890.0          17.3          79
# 69           8         350.0       160.0  4456.0          13.5          72
# 378          4         105.0        63.0  2125.0          14.7          82
# 331          4          97.0        67.0  2145.0          18.0          80
# ..         ...           ...         ...     ...           ...         ...
# 281          6         200.0        85.0  2990.0          18.2          79
# 229          8         400.0       180.0  4220.0          11.1          77
# 150          4         108.0        93.0  2391.0          15.5          74
# 145          4          83.0        61.0  2003.0          19.0          74
# 182          4         107.0        86.0  2464.0          15.5          76
#
#      Europe  Japan    USA
# 146   False  False   True
# 282   False  False   True
# 69    False  False   True
# 378   False  False   True
# 331   False   True  False
# ..      ...    ...    ...
# 281   False  False   True
# 229   False  False   True
# 150   False   True  False
# 145   False   True  False
# 182    True  False  False
#
# [314 rows x 9 columns]
#      cylinders  displacement  horsepower  weight  acceleration  model year  \
# 9            8         390.0       190.0  3850.0           8.5          70
# 25           8         360.0       215.0  4615.0          14.0          70
# 28           8         304.0       193.0  4732.0          18.5          70
# 31           4         113.0        95.0  2228.0          14.0          71
# 33           6         232.0       100.0  2634.0          13.0          71
# ..         ...           ...         ...     ...           ...         ...
# 369          4         112.0        88.0  2395.0          18.0          82
# 375          4         105.0        74.0  1980.0          15.3          82
# 382          4         108.0        70.0  2245.0          16.9          82
# 384          4          91.0        67.0  1965.0          15.7          82
# 396          4         120.0        79.0  2625.0          18.6          82
#
#      Europe  Japan    USA
# 9     False  False   True
# 25    False  False   True
# 28    False  False   True
# 31    False   True  False
# 33    False  False   True
# ..      ...    ...    ...
# 369   False  False   True
# 375    True  False  False
# 382   False   True  False
# 384   False   True  False
# 396   False  False   True
#
# [78 rows x 9 columns]
# 146    28.0
# 282    22.3
# 69     12.0
# 378    38.0
# 331    33.8
#        ...
# 281    19.8
# 229    16.0
# 150    26.0
# 145    32.0
# 182    28.0
# Name: mpg, Length: 314, dtype: float64
# 9      15.0
# 25     10.0
# 28      9.0
# 31     25.0
# 33     19.0
#        ...
# 369    34.0
# 375    36.0
# 382    34.0
# 384    32.0
# 396    28.0
# Name: mpg, Length: 78, dtype: float64

# %% [markdown]
# ## Normalization
#
# When variables are measured at different scales, they often do not contribute equally to the analysis. By normalizing the variables, we can be sure that each variable contributes equally to the analysis. Standardization is a way to normalize the data as
# $$ \tilde{x} = \frac{(x - \mu)}{\sigma}$$
# where $x$ is the input data, $\mu$ is the mean value of the data, $\sigma$ is the standard deviation of the data, and $\tilde{x}$ is the normalized data.
#
# We can use Keras normalization layer for this processing. See [keras website](https://keras.io/api/layers/preprocessing_layers/numerical/normalization/) for your reference.

# %% [markdown]
# The `describe` function returns the statistical summary of the dataframe or series. This includes count, mean, median (or 50th percentile) standard deviation, min-max, and percentile values of columns. To perform this function, chain .describe() to the dataframe. We transpose the output to show only mean and std.

# %%
df_data.describe().transpose()[['mean','std']]
# Out:
#                      mean         std
# mpg             23.445918    7.805007
# cylinders        5.471939    1.705783
# displacement   194.411990  104.644004
# horsepower     104.469388   38.491160
# weight        2977.584184  849.402560
# acceleration    15.541327    2.758864
# model year      75.979592    3.683737

# %% [markdown]
# In above cell we can see the scalability of each variable where `Europe` having the least mean and `weight` having the highest mean. If features have significantly different ranges, some features may dominate others during training.
# Therefore, rescaling the data to similar scale with noramlization helps learning. Now let us practice normalization as below.

# %% [markdown]
# ### TODO 3
#
# 1. Create `normalizer` instance using keras `Normalization` object. (HINT: use axis=-1).
# 1. Use `adapt` to learn normalization mean and standard deviations of `x_train`.
#   1. HINT: You need to convert pd.Dataframe `x_train` into numpy array.

# %%
# TODO:
normalizer = tf.keras.layers.Normalization(axis=-1)

# %%
# TODO:
normalizer.adapt(np.array(x_train))

# %%
normalizer.mean.numpy()
# Out:
# array([[5.4777069e+00, 1.9531847e+02, 1.0486943e+02, 2.9902517e+03,
#         1.5559236e+01, 7.5898087e+01, 1.7834395e-01, 1.9745223e-01,
#         6.2420380e-01]], dtype=float32)

# %%
normalizer.adapt_variance
# Out:
# <Variable path=normalization/variance, shape=(9,), dtype=float32, value=[2.8800762e+00 1.0850414e+04 1.4466995e+03 7.0989681e+05 7.7550263e+00
#  1.3467321e+01 1.4653738e-01 1.5846485e-01 2.3457341e-01]>

# %% [markdown]
# After applying normalizer we can now notice that both mean and varaince of all variables lies in similar scale

# %% [markdown]
# You can pull out one sample data from training data `x_train` as below.

# %%
x_train[:1]
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model year  \
# 146          4          90.0        75.0  2125.0          14.5          74
#
#      Europe  Japan   USA
# 146   False  False  True

# %% [markdown]
# ### TODO 3-1
#
# 1. Apply `normalizer` to the first sampe in `x_train` and check if input data are properly converted.

# %%
# TODO: #you code here
normalized_data = normalizer(x_train[:1].astype('float32'))
normalized_data
# Out:
# <tf.Tensor: shape=(1, 9), dtype=float32, numpy=
# array([[-0.87073565, -1.0110704 , -0.78530395, -1.0269395 , -0.3803653 ,
#         -0.5172201 , -0.46589085, -0.49601588,  0.77591294]],
#       dtype=float32)>

# %% [markdown]
# ## Linear Networks
#
# [Sequential](https://www.tensorflow.org/api_docs/python/tf/keras/Sequential) allows for stacking layers. We can build a linear model using keras `Sequential` object, which means that it is a linear stack of layers, where you can use the add() method to add a layer to the model (or by passing list of your stacked model).
# The first layer of the model is `normalizer` that we created above to normalize input data.
# The second layer is a `Dense` output layer with a single hidden unit to produce one output value. A `Dense` layer is a fully-connected layer, where all the units in the previous layer are connected to all the units in the current layer. The number of units in a Dense layer is specified by the units argument. In this case, the Dense layer has a single unit, which means that it is a linear model.
#
# ### TODO 4
# 1. Create `linear_model` using `Sequential` with `normalizer` and `Dense` layers. We need to make the linear model to produce one output value.

# %%
# TODO:
linear_model = tf.keras.Sequential([
    normalizer,
    layers.Dense(units=1)
])

# %% [markdown]
# The predict( ) method of a TensorFlow keras model takes an array of examples as input and returns the model's predictions for those examples. In this case, x_train[:5] is a slice of the training data containing the first 5 examples, and the model's predictions for these examples will be returned as an array.

# %%
linear_model.predict(x_train[:5])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step
# array([[ 0.49207854],
#        [ 0.8896101 ],
#        [-0.53879017],
#        [-0.16232592],
#        [ 0.68403226]], dtype=float32)

# %% [markdown]
# Comparing the output to the actual target `mpg`,

# %%
y_train[:5]
# Out:
# 146    28.0
# 282    22.3
# 69     12.0
# 378    38.0
# 331    33.8
# Name: mpg, dtype: float64

# %% [markdown]
# As you know, this model is yet trained, so having weird outputs (negative mpg?) makes sense.

# %%
x_train.shape
# Out:
# (314, 9)

# %% [markdown]
# We can see what wegith and bias the linear model have by looking and `kernel` and `bias` as below:

# %%
linear_model.layers[1].kernel #these are random weights
# Out:
# <Variable path=sequential/dense/kernel, shape=(9, 1), dtype=float32, value=[[-0.3277226 ]
#  [-0.7025851 ]
#  [ 0.03030682]
#  [ 0.5404736 ]
#  [ 0.597023  ]
#  [-0.26906252]
#  [ 0.22945571]
#  [ 0.5374857 ]
#  [ 0.69159126]]>

# %%
linear_model.layers[1].bias #bias
# Out:
# <Variable path=sequential/dense/bias, shape=(1,), dtype=float32, value=[0.]>

# %% [markdown]
# ## Complie
# Compiling a model is required to finalise the model and make it completely ready to use.
# For compilation, we need to specify an optimizer and a loss function.
# We can compile a model by using the following attribute. Let us first look at its parameters before using it.
# 1. `optimizer`: we pass the optimizer we want to use. keras implements various optimizers including SGD, Adam, etc.,
# 2. `loss`: we define a loss function (objective function) for optimization,
# 3. `metrics`: we define the metric on which we want the model to be scored.

# %% [markdown]
# ### TODO4-1
# 1. Using `compile`, prepare your model to have `SGD` as an `optimizer` with `learning_rate` 0.1 and have a loss function to be 'mean_absolute_error'.

# %%
# TODO:

linear_model.compile(
    optimizer=tf.keras.optimizers.SGD(learning_rate=0.1),
    loss='mean_absolute_error')

# %% [markdown]
# ### TODO4-2
# 1. Using `fit`, train the model with training data (`x_train` and `y_train`). Train the model for `300 epochs` keeping `verbose` turned off (0), and `validation_split` be 20%.

# %%
# this magic command in Juypter notebook allows for us to measure the time to run this cell
# let us keep this for us to figure out training time.
# %%time

# TODO:
history = linear_model.fit(
    x_train, y_train,
    epochs=300, verbose=0,
    validation_split=0.2)
# Out:
# CPU times: user 29.1 s, sys: 1.05 s, total: 30.2 s
# Wall time: 40.7 s

# %% [markdown]
# We stored the training output in `history`. Now let us observe the learning curve by plotting the training and validation loss.

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Error [MPG]')
plt.legend()

# %% [markdown]
# ### TODO4-3
# 1. `evaluate` the model on test data (`x_test` and `y_test`).

# %%
# TODO:
linear_model.evaluate(x_test, y_test)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.4017
# 2.4905238151550293

# %% [markdown]
# ## Going Deep
#
# ### TODO 5
# 1. Now  build a neural network `deep_model` with two hidden layers and one output layer as described below:
#   1. The first layer of the model should be your `normalizer` as the `linear_model`, This layer normalizes the input data.
#   1. Add two hidden layer ([Dense](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dense)) with 64 hidden units (neurons) and ReLU activation function for nonlinear transformation.
#   1. Add a output layer that produces 1 output value.
# 1. `complie` the model you have built keeping `SGD` as an `optimizer` with `learning_rate` 0.1 and have a loss function to be 'mean_absolute_error'.
# 1. Now traing the model using `fit`. You can refer to the trainig cell for `linear_model` if need.
# 1. Evaluate the model with test data.

# %%
# TODO:
deep_model = tf.keras.Sequential([
    normalizer,  # First layer is the normalizer
    tf.keras.layers.Dense(64, activation='relu'),  # First hidden layer
    tf.keras.layers.Dense(64, activation='relu'),  # Second hidden layer
    tf.keras.layers.Dense(1)  # Output layer
])





# TODO:
deep_model.compile(
    optimizer=tf.keras.optimizers.SGD(learning_rate=0.1),
    loss='mean_absolute_error'
)

# %% [markdown]
# #### Note: Learning rate:
# The learning rate determines how fast the optimizer will adjust the weights and can be an important hyperparameter to tune. A lower learning rate may result in a more accurate model but will take longer to train, while a higher learning rate may train faster but may diverge. After building the network, you can play with it see how well it learns with a specific learning rate.

# %%
# %%time
# measuring training time

# TODO:
history = deep_model.fit(
    x_train,  # Input features
    y_train,    # Target values
    epochs=300,      # Number of epochs (adjust as needed)
    batch_size=32,   # Batch size (adjust as needed)
    validation_split=0.2,  # Use 20% of training data for validation
    verbose=1        # Show training progress
)
# Out:
# Epoch 1/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 21.8104 - val_loss: 9.7922
# Epoch 2/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.5196 - val_loss: 4.6226
# Epoch 3/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.0096 - val_loss: 11.1418
# Epoch 4/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.3153 - val_loss: 4.6427
# Epoch 5/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.2769 - val_loss: 4.7600
# Epoch 6/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.5592 - val_loss: 7.2969
# Epoch 7/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.4811 - val_loss: 3.3016
# Epoch 8/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.2458 - val_loss: 6.2803
# Epoch 9/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.6977 - val_loss: 2.9336
# Epoch 10/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.9451 - val_loss: 7.0790
# Epoch 11/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.2024 - val_loss: 7.0998
# Epoch 12/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.2369 - val_loss: 4.0430
# Epoch 13/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.5936 - val_loss: 5.8292
# Epoch 14/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.9228 - val_loss: 2.7578
# Epoch 15/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.7994 - val_loss: 2.5188
# Epoch 16/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.2239 - val_loss: 3.6506
# Epoch 17/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.9920 - val_loss: 5.7391
# Epoch 18/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.9867 - val_loss: 4.6792
# Epoch 19/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.0052 - val_loss: 4.5401
# Epoch 20/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 3.4983 - val_loss: 3.7742
# Epoch 21/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.1194 - val_loss: 5.3108
# Epoch 22/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.6248 - val_loss: 2.3946
# Epoch 23/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.0587 - val_loss: 3.1984
# Epoch 24/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.7335 - val_loss: 6.8695
# Epoch 25/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.7918 - val_loss: 2.6892
# Epoch 26/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.4906 - val_loss: 2.1258
# Epoch 27/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.7029 - val_loss: 4.4485
# Epoch 28/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.2231 - val_loss: 2.6361
# Epoch 29/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.9574 - val_loss: 2.5803
# Epoch 30/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.3366 - val_loss: 2.7335
# Epoch 31/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.9987 - val_loss: 2.2291
# Epoch 32/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.7875 - val_loss: 2.1065
# Epoch 33/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.5450 - val_loss: 3.2620
# Epoch 34/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.6457 - val_loss: 2.4675
# Epoch 35/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.1182 - val_loss: 2.3173
# Epoch 36/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.3648 - val_loss: 3.0856
# Epoch 37/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.6797 - val_loss: 3.1901
# Epoch 38/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.3863 - val_loss: 4.5272
# Epoch 39/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.5883 - val_loss: 2.4555
# Epoch 40/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.8787 - val_loss: 2.6640
# Epoch 41/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.3050 - val_loss: 3.7843
# Epoch 42/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.4893 - val_loss: 4.7466
# Epoch 43/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.8235 - val_loss: 3.0131
# Epoch 44/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.0284 - val_loss: 5.8373
# Epoch 45/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.2130 - val_loss: 2.0944
# Epoch 46/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.8991 - val_loss: 3.5390
# Epoch 47/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.5174 - val_loss: 2.9726
# Epoch 48/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.1382 - val_loss: 2.8373
# Epoch 49/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.4623 - val_loss: 2.6461
# Epoch 50/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.7103 - val_loss: 2.7625
# Epoch 51/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.6250 - val_loss: 2.8151
# Epoch 52/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.8359 - val_loss: 2.5805
# Epoch 53/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.4909 - val_loss: 4.2413
# Epoch 54/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.2518 - val_loss: 2.1241
# Epoch 55/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.0783 - val_loss: 3.0835
# Epoch 56/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.2585 - val_loss: 2.5500
# Epoch 57/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.8067 - val_loss: 2.4043
# Epoch 58/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.9153 - val_loss: 2.7679
# Epoch 59/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.7466 - val_loss: 3.1755
# Epoch 60/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.5349 - val_loss: 2.3299
# Epoch 61/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.8624 - val_loss: 2.4126
# Epoch 62/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.9987 - val_loss: 2.4256
# Epoch 63/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.3177 - val_loss: 2.1817
# Epoch 64/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.1498 - val_loss: 3.1447
# Epoch 65/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.8125 - val_loss: 3.7159
# Epoch 66/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.5815 - val_loss: 2.8992
# Epoch 67/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.8854 - val_loss: 2.2787
# Epoch 68/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.1944 - val_loss: 3.1907
# Epoch 69/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.5255 - val_loss: 2.5819
# Epoch 70/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.6792 - val_loss: 2.2624
# Epoch 71/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2.1337 - val_loss: 2.3049
# Epoch 72/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.4437 - val_loss: 2.3761
# Epoch 73/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.3496 - val_loss: 2.6380
# Epoch 74/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.4212 - val_loss: 4.1139
# Epoch 75/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.1525 - val_loss: 2.4034
# Epoch 76/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.6777 - val_loss: 2.2890
# Epoch 77/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.5391 - val_loss: 2.8589
# Epoch 78/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.4522 - val_loss: 2.0796
# Epoch 79/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.2434 - val_loss: 2.7831
# Epoch 80/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.4022 - val_loss: 2.7869
# Epoch 81/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.3363 - val_loss: 2.6619
# Epoch 82/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.1265 - val_loss: 3.1343
# Epoch 83/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.8293 - val_loss: 2.2847
# Epoch 84/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.3695 - val_loss: 3.0499
# Epoch 85/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.1326 - val_loss: 2.9043
# Epoch 86/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.6590 - val_loss: 2.3975
# Epoch 87/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.6460 - val_loss: 2.3549
# Epoch 88/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.1116 - val_loss: 2.4175
# Epoch 89/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.7045 - val_loss: 2.1933
# Epoch 90/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.4474 - val_loss: 2.2712
# Epoch 91/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.1919 - val_loss: 3.3093
# Epoch 92/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.9712 - val_loss: 2.2163
# Epoch 93/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.1964 - val_loss: 4.4973
# Epoch 94/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.5600 - val_loss: 3.1923
# Epoch 95/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.7271 - val_loss: 2.4636
# Epoch 96/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.7329 - val_loss: 3.2230
# Epoch 97/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.0317 - val_loss: 2.2183
# Epoch 98/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.8608 - val_loss: 3.4387
# Epoch 99/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.1810 - val_loss: 2.3984
# Epoch 100/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.4934 - val_loss: 2.2825
# Epoch 101/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.0876 - val_loss: 3.7285
# Epoch 102/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.5808 - val_loss: 2.4479
# Epoch 103/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.1781 - val_loss: 2.3439
# Epoch 104/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.2087 - val_loss: 3.1284
# Epoch 105/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.2500 - val_loss: 3.0089
# Epoch 106/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.7471 - val_loss: 2.5829
# Epoch 107/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.5084 - val_loss: 2.2846
# Epoch 108/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.0601 - val_loss: 2.8194
# Epoch 109/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.1550 - val_loss: 2.7634
# Epoch 110/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.2708 - val_loss: 2.3502
# Epoch 111/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.1743 - val_loss: 2.4096
# Epoch 112/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.9554 - val_loss: 3.6143
# Epoch 113/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.5240 - val_loss: 2.2803
# Epoch 114/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.6660 - val_loss: 2.3021
# Epoch 115/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.3935 - val_loss: 2.5038
# Epoch 116/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.5546 - val_loss: 2.4150
# Epoch 117/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.5331 - val_loss: 3.8029
# Epoch 118/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.6616 - val_loss: 2.3759
# Epoch 119/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.3774 - val_loss: 2.2542
# Epoch 120/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.9614 - val_loss: 2.8034
# Epoch 121/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.0782 - val_loss: 2.4330
# Epoch 122/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.9518 - val_loss: 3.4779
# Epoch 123/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.7500 - val_loss: 3.0853
# Epoch 124/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.2595 - val_loss: 2.5870
# Epoch 125/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.5005 - val_loss: 3.2264
# Epoch 126/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.2345 - val_loss: 2.7965
# Epoch 127/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.4004 - val_loss: 2.2501
# Epoch 128/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.8582 - val_loss: 2.3971
# Epoch 129/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.6165 - val_loss: 2.6158
# Epoch 130/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.3124 - val_loss: 3.4355
# Epoch 131/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.4022 - val_loss: 3.4012
# Epoch 132/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.0658 - val_loss: 2.6692
# Epoch 133/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.9891 - val_loss: 3.2710
# Epoch 134/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.8939 - val_loss: 2.3280
# Epoch 135/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.3992 - val_loss: 2.3996
# Epoch 136/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.9833 - val_loss: 2.4669
# Epoch 137/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.1969 - val_loss: 2.8961
# Epoch 138/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.3672 - val_loss: 2.8310
# Epoch 139/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.8146 - val_loss: 2.3456
# Epoch 140/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.3711 - val_loss: 2.5751
# Epoch 141/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.9978 - val_loss: 2.4092
# Epoch 142/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.9919 - val_loss: 2.3343
# Epoch 143/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.4719 - val_loss: 2.4173
# Epoch 144/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.9566 - val_loss: 3.8725
# Epoch 145/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.9732 - val_loss: 3.2683
# Epoch 146/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.6557 - val_loss: 3.2492
# Epoch 147/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.9480 - val_loss: 2.3160
# Epoch 148/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.9403 - val_loss: 2.6192
# Epoch 149/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.3609 - val_loss: 2.4131
# Epoch 150/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.0535 - val_loss: 2.5023
# Epoch 151/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.5345 - val_loss: 2.4406
# Epoch 152/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.2180 - val_loss: 2.5565
# Epoch 153/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 1.8877 - val_loss: 3.5869
# Epoch 154/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.3711 - val_loss: 3.1197
# Epoch 155/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.1714 - val_loss: 3.3219
# Epoch 156/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2.2210 - val_loss: 2.6161
# Epoch 157/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.2045 - val_loss: 3.8350
# Epoch 158/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.6262 - val_loss: 2.3154
# Epoch 159/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.2297 - val_loss: 2.4834
# Epoch 160/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.0489 - val_loss: 2.1732
# Epoch 161/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.3557 - val_loss: 2.5357
# Epoch 162/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.0704 - val_loss: 2.2950
# Epoch 163/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.7964 - val_loss: 2.4004
# Epoch 164/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.7596 - val_loss: 2.3927
# Epoch 165/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.9331 - val_loss: 3.2595
# Epoch 166/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.0864 - val_loss: 2.4627
# Epoch 167/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.4115 - val_loss: 2.4002
# Epoch 168/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.1876 - val_loss: 2.3732
# Epoch 169/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.2037 - val_loss: 3.1348
# Epoch 170/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.4139 - val_loss: 2.8117
# Epoch 171/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.7567 - val_loss: 3.3751
# Epoch 172/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.5472 - val_loss: 2.2483
# Epoch 173/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.9439 - val_loss: 2.9995
# Epoch 174/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.6895 - val_loss: 4.4486
# Epoch 175/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.6090 - val_loss: 2.9736
# Epoch 176/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.3379 - val_loss: 2.9471
# Epoch 177/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.1845 - val_loss: 2.2029
# Epoch 178/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.8820 - val_loss: 2.2698
# Epoch 179/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.0539 - val_loss: 3.1084
# Epoch 180/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.0679 - val_loss: 2.2239
# Epoch 181/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.7745 - val_loss: 3.3388
# Epoch 182/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.2099 - val_loss: 2.5977
# Epoch 183/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.7269 - val_loss: 2.8656
# Epoch 184/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0619 - val_loss: 3.1778
# Epoch 185/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.8740 - val_loss: 2.6747
# Epoch 186/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.0774 - val_loss: 2.0492
# Epoch 187/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.8105 - val_loss: 2.3318
# Epoch 188/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.0349 - val_loss: 2.7686
# Epoch 189/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.5044 - val_loss: 3.4801
# Epoch 190/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.5282 - val_loss: 3.0928
# Epoch 191/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.3256 - val_loss: 2.9384
# Epoch 192/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.2776 - val_loss: 3.5140
# Epoch 193/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.4697 - val_loss: 2.6179
# Epoch 194/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.8725 - val_loss: 2.6193
# Epoch 195/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.3258 - val_loss: 2.2066
# Epoch 196/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.2033 - val_loss: 2.1390
# Epoch 197/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.8138 - val_loss: 3.2344
# Epoch 198/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.0175 - val_loss: 2.6058
# Epoch 199/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.8344 - val_loss: 2.2206
# Epoch 200/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.9574 - val_loss: 3.7218
# Epoch 201/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.4206 - val_loss: 3.3176
# Epoch 202/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.3623 - val_loss: 2.3692
# Epoch 203/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.2552 - val_loss: 2.2527
# Epoch 204/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.9990 - val_loss: 2.6294
# Epoch 205/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.3479 - val_loss: 3.0514
# Epoch 206/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.1475 - val_loss: 2.0713
# Epoch 207/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.0200 - val_loss: 2.3510
# Epoch 208/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.9640 - val_loss: 2.6699
# Epoch 209/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.0521 - val_loss: 2.9122
# Epoch 210/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.1895 - val_loss: 2.3483
# Epoch 211/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.2620 - val_loss: 2.4423
# Epoch 212/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.9134 - val_loss: 2.9961
# Epoch 213/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.1245 - val_loss: 2.4602
# Epoch 214/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.0492 - val_loss: 2.3549
# Epoch 215/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.6798 - val_loss: 2.2496
# Epoch 216/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.1173 - val_loss: 2.7454
# Epoch 217/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.9236 - val_loss: 3.0043
# Epoch 218/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.4349 - val_loss: 2.6420
# Epoch 219/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.1764 - val_loss: 2.0921
# Epoch 220/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.7410 - val_loss: 2.8171
# Epoch 221/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.3379 - val_loss: 3.9365
# Epoch 222/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.2276 - val_loss: 2.1585
# Epoch 223/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.9710 - val_loss: 2.4187
# Epoch 224/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.7874 - val_loss: 2.5052
# Epoch 225/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.6028 - val_loss: 2.6844
# Epoch 226/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.7244 - val_loss: 3.7356
# Epoch 227/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.5004 - val_loss: 2.4187
# Epoch 228/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4959 - val_loss: 2.5210
# Epoch 229/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.0818 - val_loss: 2.2296
# Epoch 230/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.8446 - val_loss: 1.9808
# Epoch 231/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.6153 - val_loss: 2.2643
# Epoch 232/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.6114 - val_loss: 4.2508
# Epoch 233/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.1101 - val_loss: 2.1371
# Epoch 234/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.0106 - val_loss: 2.8759
# Epoch 235/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.2578 - val_loss: 4.0282
# Epoch 236/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.5186 - val_loss: 2.3713
# Epoch 237/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.8338 - val_loss: 2.0905
# Epoch 238/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.9586 - val_loss: 2.5013
# Epoch 239/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 2.1675 - val_loss: 2.5242
# Epoch 240/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.7170 - val_loss: 2.1370
# Epoch 241/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.6414 - val_loss: 2.2594
# Epoch 242/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.0179 - val_loss: 2.2204
# Epoch 243/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.6906 - val_loss: 2.8012
# Epoch 244/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.8452 - val_loss: 2.8074
# Epoch 245/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.2379 - val_loss: 2.6135
# Epoch 246/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.2000 - val_loss: 2.0638
# Epoch 247/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.5911 - val_loss: 3.0060
# Epoch 248/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.0061 - val_loss: 3.7188
# Epoch 249/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.2906 - val_loss: 2.7462
# Epoch 250/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0604 - val_loss: 3.1199
# Epoch 251/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.2129 - val_loss: 2.2597
# Epoch 252/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.8539 - val_loss: 2.9782
# Epoch 253/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.9199 - val_loss: 2.5863
# Epoch 254/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.2424 - val_loss: 2.1832
# Epoch 255/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.8837 - val_loss: 2.6891
# Epoch 256/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.2591 - val_loss: 3.0985
# Epoch 257/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.2727 - val_loss: 2.4315
# Epoch 258/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.7954 - val_loss: 2.0012
# Epoch 259/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.6972 - val_loss: 2.2961
# Epoch 260/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.5830 - val_loss: 2.3530
# Epoch 261/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.8193 - val_loss: 2.3519
# Epoch 262/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4262 - val_loss: 2.2776
# Epoch 263/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.7922 - val_loss: 2.8656
# Epoch 264/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.0870 - val_loss: 2.3154
# Epoch 265/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.8763 - val_loss: 2.5378
# Epoch 266/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.4657 - val_loss: 2.3630
# Epoch 267/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.7866 - val_loss: 2.2081
# Epoch 268/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4415 - val_loss: 2.3408
# Epoch 269/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.9884 - val_loss: 2.2179
# Epoch 270/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.9389 - val_loss: 2.4491
# Epoch 271/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.6325 - val_loss: 2.2097
# Epoch 272/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.7170 - val_loss: 2.7810
# Epoch 273/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.9761 - val_loss: 2.7042
# Epoch 274/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.7676 - val_loss: 2.4201
# Epoch 275/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.0712 - val_loss: 2.6656
# Epoch 276/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.0259 - val_loss: 2.2346
# Epoch 277/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.7372 - val_loss: 2.6095
# Epoch 278/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.2682 - val_loss: 2.3797
# Epoch 279/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.6697 - val_loss: 2.3634
# Epoch 280/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.7559 - val_loss: 2.3191
# Epoch 281/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.5820 - val_loss: 3.3237
# Epoch 282/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.0259 - val_loss: 2.5468
# Epoch 283/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.7031 - val_loss: 2.1510
# Epoch 284/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.5649 - val_loss: 2.6974
# Epoch 285/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.8587 - val_loss: 2.3396
# Epoch 286/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.1071 - val_loss: 2.1597
# Epoch 287/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.7654 - val_loss: 2.2227
# Epoch 288/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.6568 - val_loss: 2.1534
# Epoch 289/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.9680 - val_loss: 2.2749
# Epoch 290/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.7622 - val_loss: 2.1516
# Epoch 291/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.7875 - val_loss: 2.5697
# Epoch 292/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.5244 - val_loss: 2.3213
# Epoch 293/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.7007 - val_loss: 2.2985
# Epoch 294/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.6083 - val_loss: 3.5044
# Epoch 295/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.1964 - val_loss: 2.2857
# Epoch 296/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.8822 - val_loss: 2.8535
# Epoch 297/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.1833 - val_loss: 2.2796
# Epoch 298/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.7368 - val_loss: 2.5719
# Epoch 299/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.9015 - val_loss: 2.2731
# Epoch 300/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.5234 - val_loss: 2.0463
# CPU times: user 35.1 s, sys: 1.5 s, total: 36.6 s
# Wall time: 45.1 s

# %% [markdown]
# Now let us visualize the learning curve to observe how it learns.

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Error [MPG]')
plt.legend()

# %%
#TODO:
test_results = deep_model.evaluate(
    x_test,
    y_test,
    verbose=1
)
print(f"Test Loss: {test_results}")
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.9580
# Test Loss: 2.229006767272949

# %% [markdown]
# ## Automatic Differentiation

# %% [markdown]
# Automatic differentiation computes the gradients for diverse complex neural network functions. We can play with simple function $y=2x^2 + 3x$ and derive the first and second order derivatives as below:

# %%
x = tf.range(5, dtype=tf.float32)
x = tf.Variable(x)

with tf.GradientTape() as gg:
    with tf.GradientTape() as g:
        y = 2*x*x + 3*x   ## (A)
    dy_dx = g.gradient(y, x)
d2y_d2x = gg.gradient(dy_dx, x)

# %% [markdown]
# The first derivative is $y^\prime = 4x+3$ so the evaluation for $x = {0,1,2,3,4}$ should match.

# %%
dy_dx
# Out:
# <tf.Tensor: shape=(5,), dtype=float32, numpy=array([ 3.,  7., 11., 15., 19.], dtype=float32)>

# %% [markdown]
# Let us check the second order $y^{\prime \prime} = 4$ now for $x = {0,1,2,3,4}$.

# %%
d2y_d2x
# Out:
# <tf.Tensor: shape=(5,), dtype=float32, numpy=array([4., 4., 4., 4., 4.], dtype=float32)>

# %% [markdown]
# ### TODO 6
# 1. Define your own function $y$. Refering the code above, compute first order derivative and validate automatic differentiation with the example inputs $x={0,1,2,3,4}.

# %%
# TODO:

x = tf.range(5, dtype=tf.float32)
x = tf.Variable(x)

with tf.GradientTape() as gg:
    with tf.GradientTape() as g:
        y = 2*x*x*x + 3*x*x  ## (A)
    dy_dx = g.gradient(y, x)
d2y_d2x = gg.gradient(dy_dx, x)

# %%
dy_dx
# Out:
# <tf.Tensor: shape=(5,), dtype=float32, numpy=array([  0.,  12.,  36.,  72., 120.], dtype=float32)>

# %%
d2y_d2x
# Out:
# <tf.Tensor: shape=(5,), dtype=float32, numpy=array([ 6., 18., 30., 42., 54.], dtype=float32)>
